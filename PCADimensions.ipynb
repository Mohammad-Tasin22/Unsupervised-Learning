# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
X, y = make_blobs(n_samples=500, n_features=5, centers=3, cluster_std=1.5, random_state=42)

# %%
X
# Out:
# array([[ -9.85712583,   9.52196609,   6.40680626,  -6.81757623,
#          -7.86054541],
#        [ -8.04717781,   8.40261648,   6.40946097,  -4.33576029,
#          -6.70289196],
#        [ -3.73690895,   6.7601386 ,   4.24877609,   0.28504117,
#          -7.10318219],
#        ...,
#        [ -5.82805   ,  -7.29173339,   7.48633693,   2.71623974,
#           7.33823548],
#        [ -2.48648271,   9.67739715,   6.21190845,   1.03031506,
#          -7.54637531],
#        [ -8.63901448, -10.68852991,   8.36601977,   4.94211449,
#           3.77070371]], shape=(500, 5))

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-1.07039133,  0.74546814,  0.0859273 , -1.58466105, -0.90798501],
#        [-0.52251206,  0.61451192,  0.08731966, -0.95761934, -0.68801347],
#        [ 0.78222538,  0.4223533 , -1.04593191,  0.20984645, -0.76407462],
#        ...,
#        [ 0.14922774, -1.22161917,  0.65212732,  0.82409945,  1.98001159],
#        [ 1.16073493,  0.7636525 , -0.01629411,  0.39814317, -0.84828797],
#        [-0.70166364, -1.61902103,  1.11350971,  1.38647649,  1.30212699]],
#       shape=(500, 5))

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
X_pca
# Out:
# array([[ 1.40522818e+00, -1.73079914e+00],
#        [ 1.03463536e+00, -9.82792414e-01],
#        [ 1.10182830e+00,  1.09084050e+00],
#        [-1.76465839e+00,  1.09970698e-01],
#        [ 8.59673831e-01, -1.63970361e+00],
#        [ 1.09738958e+00,  1.11937509e+00],
#        [ 1.04453451e+00,  1.88953610e+00],
#        [-3.14810185e+00, -1.06909853e-01],
#        [-1.34287183e+00,  7.48033000e-01],
#        [ 4.59419122e-01,  9.66806100e-01],
#        [ 1.64897776e+00,  1.95384681e+00],
#        [ 7.73369393e-01,  2.09584610e+00],
#        [-1.92869648e+00,  9.48608771e-02],
#        [ 1.15480661e+00, -1.42564791e+00],
#        [ 7.07330515e-01, -1.01056640e+00],
#        [ 1.59661674e+00, -1.64931961e+00],
#        [-2.40550592e+00, -7.53357753e-01],
#        [-1.97627695e+00, -3.59747020e-02],
#        [ 1.26193015e+00,  2.72813008e+00],
#        [ 1.58339885e+00, -1.46125327e+00],
#        [ 1.61435981e+00,  1.29812279e+00],
#        [-1.74438705e+00,  1.58820049e-01],
# ...

# %%
df_pca = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])
df_pca['label'] = y

# %%
df['ward_id'].value_counts().plot(kind='bar',color=['salmon','lightgreen'])
# Out:
# <Axes: xlabel='ward_id'>

# %%
df1 = pd.read_csv("complaints.csv")

# %%
df1.shape
# Out:
# (30, 9)

# %%
df1.head()
# Out:
#    complaint_id  citizen_id  ward_id  category_id      complaint_type  \
# 0             1          15        2            5        Water Supply
# 1             2          10        1            1  Garbage Collection
# 2             3          11        2            3        Street Light
# 3             4          13        4            2   Drainage & Sewage
# 4             5           9        5            5        Water Supply
#
#                          title  \
# 0        Water Supply issue #1
# 1  Garbage Collection issue #2
# 2        Street Light issue #3
# 3   Drainage & Sewage issue #4
# 4        Water Supply issue #5
#
#                                          description date_reported  \
# 0  Detailed description for Water Supply issue #1...     6/24/2025
# 1  Detailed description for Garbage Collection is...     4/21/2025
# 2  Detailed description for Street Light issue #3...     6/22/2025
# 3  Detailed description for Drainage & Sewage iss...     7/14/2025
# ...

# %%
df1.columns
# Out:
# Index(['complaint_id', 'citizen_id', 'ward_id', 'category_id',
#        'complaint_type', 'title', 'description', 'date_reported', 'status'],
#       dtype='object')

# %%
df1['complaint_type'].value_counts().plot(kind='bar',color=['skyblue','purple','salmon','orange','lightgreen'])
# Out:
# <Axes: xlabel='complaint_type'>

# %%
df1['status'].value_counts().plot(kind='bar',color=['green','orange',])
# Out:
# <Axes: xlabel='status'>

# %%
sns.boxplot(x = 'complaint_type', y = 'ward_id',data = df1)
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Water Supply'),
#   Text(1, 0, 'Garbage Collection'),
#   Text(2, 0, 'Street Light'),
#   Text(3, 0, 'Drainage & Sewage'),
#   Text(4, 0, 'Road & Potholes')])

# %%
sns.heatmap(df1.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df2 = pd.read_csv("actions_taken.csv")

# %%
df.head()
# Out:
#    citizen_id           name  gender       phone          address  ward_id
# 0           1    Rahim Uddin    Male  1781666241     32/B Tejgaon        5
# 1           2      Karim Ali  Female  1784363245    60/A Farmgate       10
# 2           3   Nasrin Akter  Female  1748666119    59/B Shyamoli       10
# 3           4   Sadia Khatun  Female  1779058585     90/C Gulshan        9
# 4           5  Imran Hossain  Female  1742054634  12/A Green Road        8

# %%
df1['ward_id'].value_counts().plot(kind='bar',color=['skyblue','salmon','gold','purple','lightgreen'])
# Out:
# <Axes: xlabel='ward_id'>
